# %% [markdown]
# <a href="https://colab.research.google.com/github/HRashidLiaquat/PyTorch_Learning/blob/Linear_Regression_Project/readme_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **# Project Work Flow**
#
# 1.	Import important libraries
# 2.	Get data ready (turn into tensors)
# 3.	Build A linear Regression model
# 4.	Pick a loss function and optimizer
# 5.	Build a training loop
# 6.	Evaluate your model
# 7.	Test model with new data point
# 8.	Save model

# %% [markdown]
# # *Project Name: Linear Regression*
#
#
# *   Simple linear regression project based on student result based on daily study time duraction with single feature.
# Project Tech Stack:
#      Python
#      Pytorch
#      also use deffrence python libraries see below list:
#
#      •	Import torch
#      •	Import torch.nn as nn
#      •	Import numpy as np
#      •	Import matplotlib.pyplot as plt
#      I'm using this dataset see below:
#
#      ![image.png](data:image/png;base64,...)

# %% [markdown]
# use loss Function and opptimizer
